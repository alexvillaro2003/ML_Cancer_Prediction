# %% [markdown]
# ___
# <h3 style="text-align:center;">⚠️ Este notebook documenta la fuente de datos utilizada para el proyecto y realiza una carga inicial del archivo CSV ⚠️
# </h3>
#
# ---

# %% [markdown]
# <h3 style="text-align:center;">📚🔧
# </h3>

# %%
# Importacion de Librerías:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo para gráficas:
sns.set_palette(['mediumorchid'])

# %% [markdown]
# ___
# <h3 style="text-align:center;">📊
# </h3>

# %%
# Carga de los datos
df = pd.read_csv("../data/raw/The_Cancer_data_1500_V2.csv")
fuente = 'https://www.kaggle.com/datasets/rabieelkharoua/cancer-prediction-dataset'

# Visualización de las primeras filas del dataset
print('fuente:', fuente, '(Kaggle)')
df.head()
# Out:
# fuente: https://www.kaggle.com/datasets/rabieelkharoua/cancer-prediction-dataset (Kaggle)
#    Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0   58       1  16.085313        0            1          8.146251
# 1   71       0  30.828784        0            1          9.361630
# 2   48       1  38.785084        0            2          5.135179
# 3   34       0  30.040296        0            0          9.502792
# 4   62       1  35.479721        0            0          5.356890
#
#    AlcoholIntake  CancerHistory  Diagnosis
# 0       4.148219              1          1
# 1       3.519683              0          0
# 2       4.728368              0          1
# 3       2.044636              0          0
# 4       3.309849              0          1

# %% [markdown]
# ___
# **<h3 style="text-align:center;">✏️: <u>Descripción de variables</u></h3>**
#
# | ***<p style="text-align:center;"> <u>Variable</u></p>***         | ***<p style="text-align:center;"><u>Descripción</u></p>***                                                                                                             | ***<p style="text-align:center;"><u>Tipo</u></p>***   |
# |-------------------------------|--------------------------------------------------------------------------------------------------------------------------------------|----------------------|
# | **Age**                       | Edad del paciente, valores enteros en el rango de 20 a 80 años.                                                                      | Numérica            |
# | **Gender**                    | Género del paciente; valor binario donde 0 indica Masculino y 1 indica Femenino.                                                     | Binario             |
# | **BMI**                       | Índice de masa corporal del paciente, con valores continuos en el rango de 15 a 40.                                                  | Numérica            |
# | **Smoking**                   | Estado de consumo de tabaco; valor binario donde 0 indica que el paciente No fuma y 1 indica que Sí fuma.                            | Binario             |
# | **GeneticRisk**               | Nivel de riesgo genético de cáncer, con valores categóricos donde 0 = Bajo, 1 = Medio, y 2 = Alto.                                   | Categórico          |
# | **PhysicalActivity**          | Número de horas por semana dedicadas a actividad física, con valores continuos de 0 a 10.                                            | Numérica            |
# | **AlcoholIntake**             | Consumo semanal de alcohol en unidades, con valores continuos de 0 a 5.                                                              | Numérica            |
# | **CancerHistory**             | Antecedentes personales de cáncer; valor binario donde 0 indica No y 1 indica Sí.                                                    | Binario             |
# | **Diagnosis**                 | Diagnóstico de cáncer; valor binario donde 0 indica No tiene cáncer y 1 indica Tiene cáncer.                                         | Binario             |

# %% [markdown]
# ___

# %%
# Descripción básica de los datos:
df.describe()
# Out:
#                Age       Gender          BMI      Smoking  GeneticRisk  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     50.320000     0.490667    27.513321     0.269333     0.508667
# std      17.640968     0.500080     7.230012     0.443761     0.678895
# min      20.000000     0.000000    15.000291     0.000000     0.000000
# 25%      35.000000     0.000000    21.483134     0.000000     0.000000
# 50%      51.000000     0.000000    27.598494     0.000000     0.000000
# 75%      66.000000     1.000000    33.850837     1.000000     1.000000
# max      80.000000     1.000000    39.958688     1.000000     2.000000
#
#        PhysicalActivity  AlcoholIntake  CancerHistory    Diagnosis
# count       1500.000000    1500.000000    1500.000000  1500.000000
# mean           4.897929       2.417987       0.144000     0.371333
# std            2.866162       1.419318       0.351207     0.483322
# ...

# %% [markdown]
# ___
# **<h3 style="text-align:center;">🎯: <u>Variable Objetivo</u></h3>**

# %%
# Info Variable Objetivo
df['Diagnosis'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1500 entries, 0 to 1499
# Series name: Diagnosis
# Non-Null Count  Dtype
# --------------  -----
# 1500 non-null   int64
# dtypes: int64(1)
# memory usage: 11.8 KB

# %%
# Distribución Variable Objetivo:
df['Diagnosis'].value_counts(normalize=True)
# Out:
# Diagnosis
# 0    0.628667
# 1    0.371333
# Name: proportion, dtype: float64

# %% [markdown]
# ___
# **<h3 style="text-align:center;">👀: <u>Correlaciones</u></h3>**

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True, fmt = '.2f', vmin = -1, cmap = 'coolwarm');
