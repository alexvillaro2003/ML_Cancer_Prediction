# %% [markdown]
# ___
# <h3 style="text-align:center;">⚠️ Limpieza de datos: '<u>processed.csv</u>' + '<u>train.csv</u>' + '<u>test.csv</u>' ⚠️
# </h3>
#
# ---

# %% [markdown]
# <h3 style="text-align:center;">📚🔧
# </h3>

# %%
# Importacion de Librerías:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# **<h3 style="text-align:center;">🔧: <u>Importación</u> + <u>Limpieza</u></h3>**

# %%
# Importamos 'The_Cancer_data_1500_V2.csv'
df = pd.read_csv('../data/raw/The_Cancer_data_1500_V2.csv')


# Dummies para la columna 'GeneticRisk'
df_riesgos = pd.get_dummies(df['GeneticRisk'], prefix='Riesgo')

df['Riesgo_0'] = df_riesgos['Riesgo_0'].astype(int)
df['Riesgo_1'] = df_riesgos['Riesgo_1'].astype(int)
df['Riesgo_2'] = df_riesgos['Riesgo_2'].astype(int)

df.head()
# Out:
#    Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0   58       1  16.085313        0            1          8.146251
# 1   71       0  30.828784        0            1          9.361630
# 2   48       1  38.785084        0            2          5.135179
# 3   34       0  30.040296        0            0          9.502792
# 4   62       1  35.479721        0            0          5.356890
#
#    AlcoholIntake  CancerHistory  Diagnosis  Riesgo_0  Riesgo_1  Riesgo_2
# 0       4.148219              1          1         0         1         0
# 1       3.519683              0          0         0         1         0
# 2       4.728368              0          1         0         0         1
# 3       2.044636              0          0         1         0         0
# 4       3.309849              0          1         1         0         0

# %% [markdown]
# ---
# **<h3 style="text-align:center;">⬇️ Guardar: '<u>processed.csv</u>' </h3>**

# %%
df_processed = df
df_processed.to_csv('../data/processed.csv')

# %% [markdown]
# ---
# **<h3 style="text-align:center;">➗ Separación: '<u>Data</u>'⭤   '<u>Target</u>' </h3>**

# %%
X = df.drop(['Diagnosis', 'GeneticRisk'], axis=1)
y = df['Diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ---
# **<h3 style="text-align:center;">⬇️ Guardar: '<u>train.csv</u>' </h3>**

# %%
df_train_csv = pd.DataFrame(X_train)
df_train_csv['Diagnosis'] = y_train
df_train_csv.to_csv('../data/train.csv')

df_train_csv.head()
# Out:
#       Age  Gender        BMI  Smoking  PhysicalActivity  AlcoholIntake  \
# 807    80       0  18.013960        0          3.270068       1.586276
# 1229   68       1  19.143744        0          0.945563       1.153193
# 1480   42       1  31.786979        0          6.404833       4.984953
# 1436   41       0  28.660758        0          4.036467       0.056948
# 179    34       1  39.917421        0          9.859342       2.122863
#
#       CancerHistory  Riesgo_0  Riesgo_1  Riesgo_2  Diagnosis
# 807               0         1         0         0          0
# 1229              0         1         0         0          0
# 1480              1         0         1         0          1
# 1436              0         1         0         0          1
# 179               1         0         1         0          1

# %% [markdown]
# ---
# **<h3 style="text-align:center;">⬇️ Guardar: '<u>test.csv</u>' </h3>**

# %%
df_test_csv = pd.DataFrame(X_test)
df_test_csv['Diagnosis'] = y_test
df_test_csv.to_csv('../data/test.csv')

df_test_csv.head()
# Out:
#       Age  Gender        BMI  Smoking  PhysicalActivity  AlcoholIntake  \
# 1116   46       1  30.193803        0          7.111218       2.770849
# 1368   49       1  33.547408        0          3.047609       2.570403
# 422    73       0  15.604794        0          6.579499       4.913262
# 413    41       0  25.247622        0          6.860912       1.574666
# 451    60       0  22.054677        1          7.804711       0.522402
#
#       CancerHistory  Riesgo_0  Riesgo_1  Riesgo_2  Diagnosis
# 1116              1         0         1         0          1
# 1368              0         0         0         1          1
# 422               0         1         0         0          0
# 413               0         1         0         0          0
# 451               0         1         0         0          0
